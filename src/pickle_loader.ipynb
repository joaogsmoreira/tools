# %%
import pandas as pd

PATH_CUSTOM = '/home/johny/CustomDataset/kitti_dbinfos_train.pkl'
PATH_KITTI  = '/home/johny/Kitti/kitti_dbinfos_train.pkl'

with open(PATH_KITTI, 'rb') as pkl:
    data = pd.read_pickle(pkl)

data
# Out:
# {'Pedestrian': [{'name': 'Pedestrian',
#    'path': 'gt_database/0_Pedestrian_0.bin',
#    'image_idx': 0,
#    'gt_idx': 0,
#    'box3d_lidar': array([ 8.73138176, -1.8559175 , -0.65469937,  0.47999999,  1.20000005,
#            1.88999999,  0.01      ]),
#    'num_points_in_gt': 377,
#    'difficulty': 0,
#    'group_id': 0},
#   {'name': 'Pedestrian',
#    'path': 'gt_database/10_Pedestrian_2.bin',
#    'image_idx': 10,
#    'gt_idx': 2,
#    'box3d_lidar': array([23.79977139, -8.31220424, -0.4843983 ,  0.72000003,  1.09000003,
#            1.96000004,  1.75      ]),
#    'num_points_in_gt': 23,
#    'difficulty': 0,
#    'group_id': 11},
#   {'name': 'Pedestrian',
#    'path': 'gt_database/11_Pedestrian_0.bin',
#    'image_idx': 11,
#    'gt_idx': 0,
#    'box3d_lidar': array([12.70835552, -5.04503378, -0.47577397,  0.41999999,  1.03999996,
#            1.89999998,  0.68000001]),
#    'num_points_in_gt': 152,
#    'difficulty': 0,
#    'group_id': 18},
#   {'name': 'Pedestrian',
# ...

# %%
with open(PATH_CUSTOM, 'rb') as pkl:
    data = pd.read_pickle(pkl)

data
# Out:
# {'Pedestrian': [{'name': 'Pedestrian',
#    'path': 'gt_database/0_Pedestrian_0.bin',
#    'image_idx': 0,
#    'gt_idx': 0,
#    'box3d_lidar': array([ 6.78755867,  1.05330316, -0.04300586,  0.60900003,  0.95899999,
#            1.69200003,  0.        ]),
#    'num_points_in_gt': 175,
#    'difficulty': 0,
#    'group_id': 0},
#   {'name': 'Pedestrian',
#    'path': 'gt_database/0_Pedestrian_1.bin',
#    'image_idx': 0,
#    'gt_idx': 1,
#    'box3d_lidar': array([ 4.94318176, -1.87229519,  0.03662726,  0.89899999,  0.95700002,
#            1.80499995,  0.        ]),
#    'num_points_in_gt': 296,
#    'difficulty': 0,
#    'group_id': 1},
#   {'name': 'Pedestrian',
#    'path': 'gt_database/1_Pedestrian_0.bin',
#    'image_idx': 1,
#    'gt_idx': 0,
#    'box3d_lidar': array([6.73370903, 1.22130232, 0.04756963, 0.61000001, 0.95700002,
#           1.69500005, 0.        ]),
#    'num_points_in_gt': 168,
#    'difficulty': 0,
#    'group_id': 2},
#   {'name': 'Pedestrian',
# ...
